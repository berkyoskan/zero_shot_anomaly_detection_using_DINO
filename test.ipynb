# %%
import torch

REPO_DIR = "C:\\Users\\berko\\OneDrive - Danmarks Tekniske Universitet\\DTU\\Deep Learning\\dinov3"

# Option 1: Let PyTorch Hub download weights automatically
dinov3_vits16 = torch.hub.load(REPO_DIR, 'dinov3_vits16', source='local', pretrained=True)

# Option 2: If you have the weights file, correct the path (example):
# dinov3_vits16 = torch.hub.load(REPO_DIR, 'dinov3_vits16', source='local', weights="C:\\Users\\berko\\OneDrive - Danmarks Tekniske Universitet\\DTU\\Deep Learning\\dinov3\\weights\\dinov3_vits16_pretrain_lvd1689m-08c60483.pth")

# %%
import torch

REPO_DIR = "C:\\Users\\berko\\OneDrive - Danmarks Tekniske Universitet\\DTU\\Deep Learning\\dinov3"

dinov3_vits16 = torch.hub.load(REPO_DIR, 'dinov3_vits16', source='local', weights="C:\\Users\\berko\\OneDrive - Danmarks Tekniske Universitet\\DTU\\Deep Learning\\dinov3_vits16_pretrain_lvd1689m-08c60483.pth")
# Out:
# Downloading: "file:///C:/Users/berko/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/DTU/Deep%20Learning/dinov3_vits16_pretrain_lvd1689m-08c60483.pth" to C:\Users\berko/.cache\torch\hub\checkpoints\dinov3_vits16_pretrain_lvd1689m-08c60483.pth
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\berko\miniforge3\envs\deeplproject\lib\urllib\request.py:1505, in FileHandler.open_local_file(self, req)
#    1504 try:
# -> 1505     stats = os.stat(localfile)
#    1506     size = stats.st_size
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:\\Users\\berko\\OneDrive - Danmarks Tekniske Universitet\\DTU\\Deep Learning\\dinov3_vits16_pretrain_lvd1689m-08c60483.pth'
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[8], line 5
# ...
